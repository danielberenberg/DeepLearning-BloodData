# %%
import pandas as pd

# %%
filepath1 = "../NextStartingPoint.csv"
filepath2 = "../DeepLearningClassData.csv"

nxt_strt_pt = pd.read_csv(filepath1)
deep_learning_cdata = pd.read_csv(filepath2)

subjects = list(nxt_strt_pt['Subject'])
trials = list(nxt_strt_pt['Trial'])
print(list(zip(subjects,trials)))
#print(trials)
#print(subjects)
#print([s for s in deep_learning_cdata if s in subjects])
#deep_learning_cdata[deep_learning_cdata['SUBJECT'] == 1]
nxt_starting_pt_data = pd.DataFrame(columns=["Subject", "Trial", "Heart Rate", "Respiratory Rate"])

for subj, tri in zip(subjects, trials):
    row = list(deep_learning_cdata[(deep_learning_cdata['SUBJECT'] == subj)])
    print(row)
    break
# Out:
# [(2, 1), (2, 2), (4, 1), (4, 2), (6, 1), (6, 2), (8, 2), (12, 1), (12, 2), (13, 1), (13, 2), (23, 1), (23, 2), (25, 1), (30, 1), (31, 1)]
# ['SUBJECT', 'Trial 1 Heart Rate (beats per minute)', 'Trial 1 Respiratory Rate (breaths per minute)', 'Trial 2 Heart Rate (beats per minute)', 'Trial 2 Respiratory Rate (beats per minute)']

# %%
deep_learning_cdata
# Out:
#     SUBJECT  Trial 1 Heart Rate (beats per minute)  \
# 0         1                                   64.0
# 1         2                                  100.0
# 2         3                                   60.0
# 3         4                                   56.0
# 4         5                                   70.0
# 5         6                                   78.0
# 6         7                                   81.0
# 7         8                                   60.0
# 8         9                                   78.0
# 9        10                                   66.0
# 10       11                                   44.0
# 11       12                                   74.0
# 12       13                                   80.0
# 13       14                                  102.0
# 14       15                                   70.0
# 15       16                                   84.0
# 16       17                                   70.0
# ...
